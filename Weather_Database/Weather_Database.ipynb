# %%
# Step 3 - create a new set of 2,000 random latitudes and longitudes
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather2_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather2_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d69707aef3d76685d704a6942149294

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jishou
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | san cristobal
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | port macquarie
# Processing Record 6 of Set 1 | koutsouras
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | chapais
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | yar-sale
# Processing Record 14 of Set 1 | salalah
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | thanh hoa
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | hukuntsi
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | port-gentil
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | berea
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | half moon bay
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | port augusta
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | sainte-marie
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | wakkanai
# Processing Record 35 of Set 1 | fenoarivo
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | carnot
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | dabakala
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | ngama
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | pacific grove
# Processing Record 3 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | fairbanks
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | katsuura
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | bara
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | vila velha
# Processing Record 17 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 2 | bolshoy lug
# Processing Record 19 of Set 2 | manokwari
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | kendari
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | toktogul
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | antofagasta
# Processing Record 27 of Set 2 | kununurra
# Processing Record 28 of Set 2 | kahului
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | mount isa
# Processing Record 31 of Set 2 | cabedelo
# Processing Record 32 of Set 2 | adrar
# Processing Record 33 of Set 2 | coahuayana
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | fortuna
# Processing Record 36 of Set 2 | tuatapere
# Processing Record 37 of Set 2 | behbahan
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | tumut
# Processing Record 41 of Set 2 | malanje
# Processing Record 42 of Set 2 | mehamn
# Processing Record 43 of Set 2 | loandjili
# Processing Record 44 of Set 2 | broken hill
# Processing Record 45 of Set 2 | san andres
# Processing Record 46 of Set 2 | morehead
# Processing Record 47 of Set 2 | luganville
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | mount gambier
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | zhovti vody
# Processing Record 3 of Set 3 | bulalacao
# Processing Record 4 of Set 3 | taksimo
# Processing Record 5 of Set 3 | havoysund
# Processing Record 6 of Set 3 | ceres
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | siocon
# Processing Record 9 of Set 3 | bacolod
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | rio gallegos
# Processing Record 12 of Set 3 | ahipara
# Processing Record 13 of Set 3 | borogontsy
# Processing Record 14 of Set 3 | bartlesville
# Processing Record 15 of Set 3 | goderich
# Processing Record 16 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 3 | chicama
# Processing Record 19 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | leh
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | muhos
# Processing Record 24 of Set 3 | la ronge
# Processing Record 25 of Set 3 | tiznit
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | ohara
# Processing Record 29 of Set 3 | aranos
# Processing Record 30 of Set 3 | henties bay
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | mataura
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | kempsey
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | bahia blanca
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | hofn
# Processing Record 41 of Set 3 | poum
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | bukachacha
# Processing Record 46 of Set 3 | vostok
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | mercedes
# Processing Record 49 of Set 3 | san vicente
# Processing Record 50 of Set 3 | vitoria
# Processing Record 1 of Set 4 | bartica
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | santa rosa
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | nome
# Processing Record 6 of Set 4 | sakakah
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | namibe
# Processing Record 9 of Set 4 | souillac
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | bethel
# Processing Record 13 of Set 4 | gemena
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 4 | alofi
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | talara
# Processing Record 21 of Set 4 | burica
# City not found. Skipping...
# Processing Record 22 of Set 4 | saravan
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | vallenar
# Processing Record 25 of Set 4 | lata
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | bulgan
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | daan
# Processing Record 32 of Set 4 | catamarca
# Processing Record 33 of Set 4 | bilibino
# Processing Record 34 of Set 4 | vila franca do campo
# Processing Record 35 of Set 4 | albion
# Processing Record 36 of Set 4 | kloulklubed
# Processing Record 37 of Set 4 | paita
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | saint-augustin
# Processing Record 40 of Set 4 | araouane
# Processing Record 41 of Set 4 | unai
# Processing Record 42 of Set 4 | ravar
# Processing Record 43 of Set 4 | barra do garcas
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | hastings
# Processing Record 46 of Set 4 | bouar
# Processing Record 47 of Set 4 | gat
# Processing Record 48 of Set 4 | oudtshoorn
# Processing Record 49 of Set 4 | buala
# Processing Record 50 of Set 4 | pantelho
# Processing Record 1 of Set 5 | aklavik
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | porangatu
# Processing Record 4 of Set 5 | oeiras
# Processing Record 5 of Set 5 | mildura
# Processing Record 6 of Set 5 | lasa
# Processing Record 7 of Set 5 | ejura
# Processing Record 8 of Set 5 | borovskoy
# Processing Record 9 of Set 5 | tabou
# Processing Record 10 of Set 5 | te anau
# Processing Record 11 of Set 5 | urla
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | kampot
# Processing Record 14 of Set 5 | jequie
# Processing Record 15 of Set 5 | pingliang
# Processing Record 16 of Set 5 | esmeraldas
# Processing Record 17 of Set 5 | bengkulu
# Processing Record 18 of Set 5 | nuuk
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | ancud
# Processing Record 21 of Set 5 | kuroishi
# Processing Record 22 of Set 5 | ballina
# Processing Record 23 of Set 5 | jacqueville
# Processing Record 24 of Set 5 | saint-georges
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | palmer
# Processing Record 27 of Set 5 | castro
# Processing Record 28 of Set 5 | beringovskiy
# Processing Record 29 of Set 5 | dinguiraye
# Processing Record 30 of Set 5 | novaya ladoga
# Processing Record 31 of Set 5 | nelson bay
# Processing Record 32 of Set 5 | ha tinh
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | elizabethton
# Processing Record 35 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 5 | nacala
# Processing Record 37 of Set 5 | rio grande
# Processing Record 38 of Set 5 | deep river
# Processing Record 39 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 40 of Set 5 | bardiyah
# Processing Record 41 of Set 5 | angoche
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | launceston
# Processing Record 45 of Set 5 | arman
# Processing Record 46 of Set 5 | asyut
# Processing Record 47 of Set 5 | port-cartier
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | nemuro
# Processing Record 50 of Set 5 | saskylakh
# Processing Record 1 of Set 6 | san quintin
# Processing Record 2 of Set 6 | saint-pierre
# Processing Record 3 of Set 6 | uinskoye
# Processing Record 4 of Set 6 | yellowknife
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | safranbolu
# Processing Record 8 of Set 6 | muravlenko
# Processing Record 9 of Set 6 | gusau
# Processing Record 10 of Set 6 | viedma
# Processing Record 11 of Set 6 | collie
# Processing Record 12 of Set 6 | oyama
# Processing Record 13 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 14 of Set 6 | vestmannaeyjar
# Processing Record 15 of Set 6 | itoman
# Processing Record 16 of Set 6 | kemin
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | iquitos
# Processing Record 20 of Set 6 | jining
# Processing Record 21 of Set 6 | fougeres
# Processing Record 22 of Set 6 | aporawan
# City not found. Skipping...
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | gushikawa
# Processing Record 25 of Set 6 | sao filipe
# Processing Record 26 of Set 6 | vicuna
# Processing Record 27 of Set 6 | anaconda
# Processing Record 28 of Set 6 | samarai
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | mar del plata
# Processing Record 31 of Set 6 | carutapera
# Processing Record 32 of Set 6 | gizo
# Processing Record 33 of Set 6 | olafsvik
# Processing Record 34 of Set 6 | sabha
# Processing Record 35 of Set 6 | haysville
# Processing Record 36 of Set 6 | puerto ayora
# Processing Record 37 of Set 6 | makakilo city
# Processing Record 38 of Set 6 | elko
# Processing Record 39 of Set 6 | marawi
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | nhulunbuy
# Processing Record 42 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 6 | giporlos
# Processing Record 44 of Set 6 | itaqui
# Processing Record 45 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 6 | megion
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | boa vista
# Processing Record 49 of Set 6 | eureka
# Processing Record 50 of Set 6 | berdigestyakh
# Processing Record 1 of Set 7 | caravelas
# Processing Record 2 of Set 7 | oktyabrskoye
# Processing Record 3 of Set 7 | liverpool
# Processing Record 4 of Set 7 | alice springs
# Processing Record 5 of Set 7 | zeya
# Processing Record 6 of Set 7 | sur
# Processing Record 7 of Set 7 | santa cruz
# Processing Record 8 of Set 7 | touros
# Processing Record 9 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 7 | labuan
# Processing Record 11 of Set 7 | qaqortoq
# Processing Record 12 of Set 7 | saint-francois
# Processing Record 13 of Set 7 | newport
# Processing Record 14 of Set 7 | loudi
# Processing Record 15 of Set 7 | zhigansk
# Processing Record 16 of Set 7 | morristown
# Processing Record 17 of Set 7 | kuytun
# Processing Record 18 of Set 7 | coquimbo
# Processing Record 19 of Set 7 | erice
# Processing Record 20 of Set 7 | ojinaga
# Processing Record 21 of Set 7 | yambio
# Processing Record 22 of Set 7 | nenjiang
# Processing Record 23 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | lakes entrance
# Processing Record 26 of Set 7 | evensk
# Processing Record 27 of Set 7 | rosamorada
# Processing Record 28 of Set 7 | buin
# Processing Record 29 of Set 7 | teya
# Processing Record 30 of Set 7 | dalaba
# Processing Record 31 of Set 7 | beloha
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | ixtapa
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | mafeteng
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 38 of Set 7 | sampit
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | saryozek
# Processing Record 41 of Set 7 | pallasovka
# Processing Record 42 of Set 7 | yulin
# Processing Record 43 of Set 7 | paso de carrasco
# Processing Record 44 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 7 | coihaique
# Processing Record 46 of Set 7 | atar
# Processing Record 47 of Set 7 | boyolangu
# Processing Record 48 of Set 7 | srednekolymsk
# Processing Record 49 of Set 7 | wukari
# Processing Record 50 of Set 7 | senanga
# Processing Record 1 of Set 8 | taltal
# Processing Record 2 of Set 8 | buchanan
# Processing Record 3 of Set 8 | mackay
# Processing Record 4 of Set 8 | rognan
# Processing Record 5 of Set 8 | spassk
# Processing Record 6 of Set 8 | meadow lake
# Processing Record 7 of Set 8 | sassandra
# Processing Record 8 of Set 8 | howard springs
# Processing Record 9 of Set 8 | dunedin
# Processing Record 10 of Set 8 | yenagoa
# Processing Record 11 of Set 8 | north platte
# Processing Record 12 of Set 8 | sirvintos
# Processing Record 13 of Set 8 | willowmore
# Processing Record 14 of Set 8 | sydney
# Processing Record 15 of Set 8 | corinto
# Processing Record 16 of Set 8 | berlevag
# Processing Record 17 of Set 8 | vardo
# Processing Record 18 of Set 8 | esperance
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | bay roberts
# Processing Record 21 of Set 8 | pingdu
# Processing Record 22 of Set 8 | slave lake
# Processing Record 23 of Set 8 | borba
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | the valley
# Processing Record 26 of Set 8 | zambezi
# Processing Record 27 of Set 8 | pauini
# Processing Record 28 of Set 8 | kalmunai
# Processing Record 29 of Set 8 | muros
# Processing Record 30 of Set 8 | sri aman
# Processing Record 31 of Set 8 | thinadhoo
# Processing Record 32 of Set 8 | healesville
# Processing Record 33 of Set 8 | neiafu
# Processing Record 34 of Set 8 | grand gaube
# Processing Record 35 of Set 8 | mareeba
# Processing Record 36 of Set 8 | pascagoula
# Processing Record 37 of Set 8 | leningradskiy
# Processing Record 38 of Set 8 | lima
# Processing Record 39 of Set 8 | alyangula
# Processing Record 40 of Set 8 | kailua
# Processing Record 41 of Set 8 | skiros
# City not found. Skipping...
# Processing Record 42 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 8 | padang
# Processing Record 44 of Set 8 | daru
# Processing Record 45 of Set 8 | katherine
# Processing Record 46 of Set 8 | hasaki
# Processing Record 47 of Set 8 | greymouth
# Processing Record 48 of Set 8 | barra patuca
# Processing Record 49 of Set 8 | jiayuguan
# Processing Record 50 of Set 8 | longyearbyen
# Processing Record 1 of Set 9 | timmins
# Processing Record 2 of Set 9 | pevek
# Processing Record 3 of Set 9 | dondo
# Processing Record 4 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 9 | rosetta
# Processing Record 6 of Set 9 | namtsy
# Processing Record 7 of Set 9 | montepuez
# Processing Record 8 of Set 9 | george town
# Processing Record 9 of Set 9 | wuwei
# Processing Record 10 of Set 9 | ossora
# Processing Record 11 of Set 9 | nabire
# Processing Record 12 of Set 9 | nynashamn
# Processing Record 13 of Set 9 | buzmeyin
# Processing Record 14 of Set 9 | pierre
# Processing Record 15 of Set 9 | gawler
# Processing Record 16 of Set 9 | rafraf
# Processing Record 17 of Set 9 | antsohihy
# Processing Record 18 of Set 9 | amapa
# Processing Record 19 of Set 9 | saldanha
# Processing Record 20 of Set 9 | catemaco
# Processing Record 21 of Set 9 | kodinsk
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | westport
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | mozarlandia
# Processing Record 26 of Set 9 | severo-kurilsk
# Processing Record 27 of Set 9 | verkhoyansk
# Processing Record 28 of Set 9 | tarakan
# Processing Record 29 of Set 9 | lhokseumawe
# Processing Record 30 of Set 9 | cururupu
# Processing Record 31 of Set 9 | chermoz
# Processing Record 32 of Set 9 | cap-aux-meules
# Processing Record 33 of Set 9 | progreso
# Processing Record 34 of Set 9 | luquillo
# Processing Record 35 of Set 9 | empalme
# Processing Record 36 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 9 | asau
# Processing Record 38 of Set 9 | turukhansk
# Processing Record 39 of Set 9 | bairiki
# Processing Record 40 of Set 9 | bereda
# Processing Record 41 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 42 of Set 9 | jaru
# Processing Record 43 of Set 9 | zhireken
# Processing Record 44 of Set 9 | mogadishu
# Processing Record 45 of Set 9 | college
# Processing Record 46 of Set 9 | acarau
# Processing Record 47 of Set 9 | iracoubo
# Processing Record 48 of Set 9 | havre-saint-pierre
# Processing Record 49 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 9 | strezhevoy
# Processing Record 1 of Set 10 | macia
# Processing Record 2 of Set 10 | aden
# Processing Record 3 of Set 10 | christchurch
# Processing Record 4 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 10 | altay
# Processing Record 6 of Set 10 | kungurtug
# Processing Record 7 of Set 10 | faya
# Processing Record 8 of Set 10 | scottsbluff
# Processing Record 9 of Set 10 | ahuimanu
# Processing Record 10 of Set 10 | madras
# Processing Record 11 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 10 | maldonado
# Processing Record 13 of Set 10 | sapucaia
# Processing Record 14 of Set 10 | sutton
# Processing Record 15 of Set 10 | el alto
# Processing Record 16 of Set 10 | necochea
# Processing Record 17 of Set 10 | cape coast
# Processing Record 18 of Set 10 | roald
# Processing Record 19 of Set 10 | komsomolskiy
# Processing Record 20 of Set 10 | kindu
# Processing Record 21 of Set 10 | dusseldorf
# Processing Record 22 of Set 10 | medina del campo
# Processing Record 23 of Set 10 | takestan
# Processing Record 24 of Set 10 | meulaboh
# Processing Record 25 of Set 10 | chernyshevskiy
# Processing Record 26 of Set 10 | acajutla
# Processing Record 27 of Set 10 | ordzhonikidze
# Processing Record 28 of Set 10 | khash
# Processing Record 29 of Set 10 | riacho de santana
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | khandbari
# Processing Record 32 of Set 10 | sao desiderio
# Processing Record 33 of Set 10 | castrillon
# Processing Record 34 of Set 10 | yarensk
# Processing Record 35 of Set 10 | araguatins
# City not found. Skipping...
# Processing Record 36 of Set 10 | buenaventura
# Processing Record 37 of Set 10 | tigil
# Processing Record 38 of Set 10 | erenhot
# Processing Record 39 of Set 10 | uvira
# Processing Record 40 of Set 10 | russell
# Processing Record 41 of Set 10 | batagay-alyta
# Processing Record 42 of Set 10 | la gaulette
# City not found. Skipping...
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | todos santos
# Processing Record 45 of Set 10 | calama
# Processing Record 46 of Set 10 | mana
# Processing Record 47 of Set 10 | sabzevar
# Processing Record 48 of Set 10 | kirkenes
# Processing Record 49 of Set 10 | dongtai
# Processing Record 50 of Set 10 | abu dhabi
# Processing Record 1 of Set 11 | bitung
# Processing Record 2 of Set 11 | rawson
# Processing Record 3 of Set 11 | businga
# Processing Record 4 of Set 11 | male
# Processing Record 5 of Set 11 | benguela
# Processing Record 6 of Set 11 | saint-joseph
# Processing Record 7 of Set 11 | kulob
# Processing Record 8 of Set 11 | kirakira
# Processing Record 9 of Set 11 | insar
# Processing Record 10 of Set 11 | dongying
# Processing Record 11 of Set 11 | raudeberg
# Processing Record 12 of Set 11 | zyryanka
# Processing Record 13 of Set 11 | gravelbourg
# Processing Record 14 of Set 11 | angra
# City not found. Skipping...
# Processing Record 15 of Set 11 | mastic beach
# Processing Record 16 of Set 11 | finsterwalde
# Processing Record 17 of Set 11 | kavaratti
# Processing Record 18 of Set 11 | guane
# Processing Record 19 of Set 11 | mocuba
# Processing Record 20 of Set 11 | ostrovnoy
# Processing Record 21 of Set 11 | comodoro rivadavia
# Processing Record 22 of Set 11 | vao
# Processing Record 23 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 25 of Set 11 | sibolga
# Processing Record 26 of Set 11 | penzance
# Processing Record 27 of Set 11 | changji
# Processing Record 28 of Set 11 | nyandoma
# Processing Record 29 of Set 11 | kayerkan
# Processing Record 30 of Set 11 | svetlogorsk
# Processing Record 31 of Set 11 | copacabana
# Processing Record 32 of Set 11 | mayo
# Processing Record 33 of Set 11 | tilichiki
# Processing Record 34 of Set 11 | olsztyn
# Processing Record 35 of Set 11 | pokhara
# Processing Record 36 of Set 11 | boende
# Processing Record 37 of Set 11 | skeldon
# Processing Record 38 of Set 11 | rozkishne
# Processing Record 39 of Set 11 | falaleu
# City not found. Skipping...
# Processing Record 40 of Set 11 | grindavik
# Processing Record 41 of Set 11 | vila do maio
# Processing Record 42 of Set 11 | bac lieu
# Processing Record 43 of Set 11 | golden
# Processing Record 44 of Set 11 | uyuni
# Processing Record 45 of Set 11 | stykkisholmur
# Processing Record 46 of Set 11 | istok
# Processing Record 47 of Set 11 | bosaso
# Processing Record 48 of Set 11 | margate
# Processing Record 49 of Set 11 | tampere
# Processing Record 50 of Set 11 | agadez
# Processing Record 1 of Set 12 | raga
# Processing Record 2 of Set 12 | corowa
# Processing Record 3 of Set 12 | youhao
# Processing Record 4 of Set 12 | hovd
# Processing Record 5 of Set 12 | sinnamary
# Processing Record 6 of Set 12 | timra
# Processing Record 7 of Set 12 | shahr-e babak
# Processing Record 8 of Set 12 | igrim
# Processing Record 9 of Set 12 | moyamba
# Processing Record 10 of Set 12 | hays
# Processing Record 11 of Set 12 | kenora
# Processing Record 12 of Set 12 | conceicao da barra
# Processing Record 13 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 14 of Set 12 | rengo
# Processing Record 15 of Set 12 | cravo norte
# Processing Record 16 of Set 12 | mathbaria
# Processing Record 17 of Set 12 | boffa
# Processing Record 18 of Set 12 | morro bay
# Processing Record 19 of Set 12 | obera
# Processing Record 20 of Set 12 | enshi
# Processing Record 21 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 12 | santo andre
# Processing Record 23 of Set 12 | kalispell
# Processing Record 24 of Set 12 | san borja
# Processing Record 25 of Set 12 | pinyug
# Processing Record 26 of Set 12 | hermagor
# Processing Record 27 of Set 12 | dahra
# Processing Record 28 of Set 12 | sapele
# Processing Record 29 of Set 12 | shelburne
# Processing Record 30 of Set 12 | conde
# Processing Record 31 of Set 12 | sambava
# Processing Record 32 of Set 12 | oranjestad
# Processing Record 33 of Set 12 | nueva loja
# Processing Record 34 of Set 12 | lere
# Processing Record 35 of Set 12 | high rock
# Processing Record 36 of Set 12 | anadyr
# Processing Record 37 of Set 12 | ketchikan
# Processing Record 38 of Set 12 | plouzane
# Processing Record 39 of Set 12 | vasterhaninge
# Processing Record 40 of Set 12 | sungaipenuh
# Processing Record 41 of Set 12 | oriximina
# Processing Record 42 of Set 12 | athabasca
# Processing Record 43 of Set 12 | noumea
# Processing Record 44 of Set 12 | quatre cocos
# Processing Record 45 of Set 12 | tual
# Processing Record 46 of Set 12 | luangwa
# Processing Record 47 of Set 12 | luau
# Processing Record 48 of Set 12 | sao lourenco do oeste
# Processing Record 49 of Set 12 | kankavli
# City not found. Skipping...
# Processing Record 50 of Set 12 | killybegs
# Processing Record 1 of Set 13 | rocha
# Processing Record 2 of Set 13 | terrace
# Processing Record 3 of Set 13 | kashmor
# Processing Record 4 of Set 13 | temir
# Processing Record 5 of Set 13 | lexington park
# Processing Record 6 of Set 13 | batticaloa
# Processing Record 7 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 8 of Set 13 | dromolaxia
# Processing Record 9 of Set 13 | abu kamal
# Processing Record 10 of Set 13 | trinidad
# Processing Record 11 of Set 13 | tombouctou
# Processing Record 12 of Set 13 | praia da vitoria
# Processing Record 13 of Set 13 | walvis bay
# Processing Record 14 of Set 13 | preston
# Processing Record 15 of Set 13 | caconda
# Processing Record 16 of Set 13 | kabalo
# Processing Record 17 of Set 13 | pachora
# Processing Record 18 of Set 13 | mnogovershinnyy
# Processing Record 19 of Set 13 | ampanihy
# Processing Record 20 of Set 13 | uribia
# Processing Record 21 of Set 13 | flinders
# Processing Record 22 of Set 13 | saiha
# Processing Record 23 of Set 13 | bayir
# Processing Record 24 of Set 13 | mombasa
# Processing Record 25 of Set 13 | nalut
# Processing Record 26 of Set 13 | sao joao da barra
# Processing Record 27 of Set 13 | conakry
# Processing Record 28 of Set 13 | thunder bay
# Processing Record 29 of Set 13 | maues
# Processing Record 30 of Set 13 | sulangan
# Processing Record 31 of Set 13 | tadine
# Processing Record 32 of Set 13 | den helder
# Processing Record 33 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 13 | naryan-mar
# Processing Record 35 of Set 13 | sexsmith
# Processing Record 36 of Set 13 | pontes e lacerda
# Processing Record 37 of Set 13 | lavrentiya
# Processing Record 38 of Set 13 | takahashi
# Processing Record 39 of Set 13 | plettenberg bay
# Processing Record 40 of Set 13 | krasnyy kut
# Processing Record 41 of Set 13 | yola
# Processing Record 42 of Set 13 | santa cruz del norte
# Processing Record 43 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 13 | krasnoselkup
# Processing Record 45 of Set 13 | fontenay-le-comte
# Processing Record 46 of Set 13 | khor
# Processing Record 47 of Set 13 | general roca
# Processing Record 48 of Set 13 | mlonggo
# Processing Record 49 of Set 13 | kolokani
# Processing Record 50 of Set 13 | chara
# Processing Record 1 of Set 14 | grand forks
# Processing Record 2 of Set 14 | ucar
# Processing Record 3 of Set 14 | zhangjiakou
# Processing Record 4 of Set 14 | shitanjing
# Processing Record 5 of Set 14 | qazanbulaq
# Processing Record 6 of Set 14 | okhotsk
# Processing Record 7 of Set 14 | hualmay
# Processing Record 8 of Set 14 | mianwali
# Processing Record 9 of Set 14 | avera
# Processing Record 10 of Set 14 | mitsamiouli
# Processing Record 11 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 14 | tottori
# Processing Record 13 of Set 14 | borzya
# Processing Record 14 of Set 14 | maple creek
# Processing Record 15 of Set 14 | diapaga
# Processing Record 16 of Set 14 | suoyarvi
# Processing Record 17 of Set 14 | khani
# Processing Record 18 of Set 14 | carballo
# Processing Record 19 of Set 14 | clarence town
# Processing Record 20 of Set 14 | aragona
# Processing Record 21 of Set 14 | fuengirola
# Processing Record 22 of Set 14 | sioux lookout
# Processing Record 23 of Set 14 | pahrump
# Processing Record 24 of Set 14 | malinao
# Processing Record 25 of Set 14 | hervey bay
# Processing Record 26 of Set 14 | haines junction
# Processing Record 27 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 14 | tavricheskoye
# Processing Record 29 of Set 14 | ramsar
# Processing Record 30 of Set 14 | ati
# Processing Record 31 of Set 14 | banganapalle
# Processing Record 32 of Set 14 | havelock
# Processing Record 33 of Set 14 | ipil
# Processing Record 34 of Set 14 | palasa
# Processing Record 35 of Set 14 | ghorawal
# Processing Record 36 of Set 14 | nyrob
# Processing Record 37 of Set 14 | camacha
# Processing Record 38 of Set 14 | konstantinovka
# Processing Record 39 of Set 14 | hobyo
# Processing Record 40 of Set 14 | dhanwar
# Processing Record 41 of Set 14 | grobina
# Processing Record 42 of Set 14 | sunrise manor
# Processing Record 43 of Set 14 | khorinsk
# Processing Record 44 of Set 14 | xining
# Processing Record 45 of Set 14 | north bend
# Processing Record 46 of Set 14 | man
# Processing Record 47 of Set 14 | lillesand
# Processing Record 48 of Set 14 | magan
# Processing Record 49 of Set 14 | bandarbeyla
# Processing Record 50 of Set 14 | fort saint james
# Processing Record 1 of Set 15 | denpasar
# Processing Record 2 of Set 15 | spornoye
# Processing Record 3 of Set 15 | islamkot
# Processing Record 4 of Set 15 | gualaquiza
# Processing Record 5 of Set 15 | nushki
# Processing Record 6 of Set 15 | reykjavik
# Processing Record 7 of Set 15 | kawalu
# Processing Record 8 of Set 15 | biak
# Processing Record 9 of Set 15 | algeciras
# Processing Record 10 of Set 15 | pathein
# Processing Record 11 of Set 15 | colares
# Processing Record 12 of Set 15 | quimper
# Processing Record 13 of Set 15 | mahanoro
# Processing Record 14 of Set 15 | miraflores
# Processing Record 15 of Set 15 | raver
# Processing Record 16 of Set 15 | dingle
# Processing Record 17 of Set 15 | cuicatlan
# Processing Record 18 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 15 | moanda
# Processing Record 20 of Set 15 | korla
# Processing Record 21 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 15 | batesville
# Processing Record 23 of Set 15 | zhezkazgan
# Processing Record 24 of Set 15 | jhargram
# Processing Record 25 of Set 15 | ullal
# Processing Record 26 of Set 15 | puerto quijarro
# Processing Record 27 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 15 | homer
# Processing Record 29 of Set 15 | sept-iles
# Processing Record 30 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 31 of Set 15 | astoria
# Processing Record 32 of Set 15 | soe
# Processing Record 33 of Set 15 | namatanai
# Processing Record 34 of Set 15 | champerico
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6a25690bf9be> in <module>
#       1 # Convert the array of dictionaries to a Pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#       3 city_data_df
#
# NameError: name 'city_data' is not defined

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
